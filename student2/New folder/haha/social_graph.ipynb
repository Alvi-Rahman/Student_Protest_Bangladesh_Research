# %%
import numpy as np
import pandas as pd

# %%
bnpjamaat = pd.read_excel('bnpjamaat.xlsx',index_col=0)

# %%
bnpjamaat.head()
# Out:
#                     usernameTweet  \
# ID
# 1027070401451570048    MAlamHanif
# 1026808311063049984    MAlamHanif
# 1026558533872089984    DeadTonmoy
# 1026471854062450048    DeadTonmoy
# 1026472749441510016   PijonZimtuj
#
#                                                                   text  \
# ID
# 1027070401451570048  A group of people still blocking the roads eve...
# 1026808311063049984  # Bangladesh govt already accepted the 9 deman...
# 1026558533872089984  A non political movement demanding #SafeRoadsF...
# 1026471854062450048  The #Bangladesh govt already accepted the 9 de...
# 1026472749441510016  The #Bangladesh govt already accepted the 9 de...
#
#                                                          url  nbr_retweet  \
# ID
# 1027070401451570048   /MAlamHanif/status/1027070401451573248           10
# 1026808311063049984   /MAlamHanif/status/1026808311063052289           12
# 1026558533872089984   /DeadTonmoy/status/1026558533872099335            4
# ...

# %%
bnpjamaat.tail()
# Out:
#                      usernameTweet  \
# ID
# 1027903194427340032     tauhidul97
# 1027903975310240000    Tareqjkkniu
# 1027910089829760000  chiranjibamit
# 1027938810435270016     SyedTito71
# 1028279863038200064      FM_Pavel3
#
#                                                                   text  \
# ID
# 1027903194427340032  # BNPjamaat Conspirators tried to turn the stu...
# 1027903975310240000  # BNPjamaat Conspirators tried to turn the stu...
# 1027910089829760000  Conspiracy in the shadow of student movement.....
# 1027938810435270016  Conspiracy in the shadow of student movement.....
# 1028279863038200064  # BNPjamaat Conspirators tried to turn the stu...
#
#                                                            url  nbr_retweet  \
# ID
# 1027903194427340032     /tauhidul97/status/1027903194427342853            0
# 1027903975310240000    /Tareqjkkniu/status/1027903975310249986            0
# 1027910089829760000  /chiranjibamit/status/1027910089829765126            0
# ...

# %%
len(bnpjamaat)
# Out:
# 2737

# %%
len(bnpjamaat['user_id'].unique())
# Out:
# 240

# %%
len(bnpjamaat['usernameTweet'].unique())
# Out:
# 240

# %%
type(bnpjamaat['user_id'].unique())
# Out:
# numpy.ndarray

# %%
bj_tuple = [(1,2),(2,1),(4,2),(4,7),(4,3)]

# %%
user_id_lst = list(bnpjamaat['user_id'].unique())

# %%
follower = pd.read_excel('follower_followed.xlsx',index_col=0)
follower_bj = follower.loc[user_id_lst].copy()
follower_bj.dropna(inplace=True)
follower = list(follower_bj.index)


followed = pd.read_excel('follower_followed.xlsx',index_col=1)
followed_bj = followed.loc[user_id_lst].copy()
followed_bj.dropna(inplace=True)
followed = list(followed_bj.index)


followed = list(set(followed))
follower = list(set(follower))
# Out:
# c:\users\alvira~1\deeple~1\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#
# c:\users\alvira~1\deeple~1\lib\site-packages\ipykernel_launcher.py:8: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike

# %%
bj_dict = {}
for i in range(len(followed)):
    if followed[i] in follower:
        bj_dict[followed[i]] = True

        
for i in range(len(follower)):
    if follower[i] in followed:
        bj_dict[follower[i]] = True

# %%
len(followed)
# Out:
# 113

# %%
len(follower)
# Out:
# 117

# %%
len(bj_dict)
# Out:
# 112

# %%
all_bj = list(bj_dict.keys())
not_in_bj = [followed[i] for i in range(len(followed)) if followed[i] not in all_bj]
not_in_bj.extend([follower[i] for i in range(len(follower)) if follower[i] not in all_bj])
not_in_bj
# Out:
# [425347635, 3012293286, 3010980588, 3023364448, 3021219682, 3021166457]

# %%
len(all_bj)
# Out:
# 112

# %%
##############step hasina#######################

# %%
stepdownhasina = pd.read_excel('stepdownhasina.xlsx',index_col=0)

stepdownhasina.head()

user_id_lst = list(stepdownhasina['user_id'].unique())

len(user_id_lst)
# Out:
# 27

# %%
follower = pd.read_excel('follower_followed.xlsx',index_col=0)
follower_step_hasina = follower.loc[user_id_lst].copy()
follower_step_hasina.dropna(inplace=True)
follower = list(follower_step_hasina.index)

followed = pd.read_excel('follower_followed.xlsx',index_col=1)
followed_step_hasina = followed.loc[user_id_lst].copy()
followed_step_hasina.dropna(inplace=True)
followed = list(followed_step_hasina.index)

followed = list(set(followed))
follower = list(set(follower))

# %%
step_hasina_dict = {}
for i in range(len(followed)):
    if followed[i] in follower:
        step_hasina_dict[followed[i]] = True

        
for i in range(len(follower)):
    if follower[i] in followed:
        step_hasina_dict[follower[i]] = True

# %%
len(step_hasina_dict)
# Out:
# 27

# %%
all_step_hasina = list(step_hasina_dict.keys())
not_in_step_hasina = [followed[i] for i in range(len(followed)) if followed[i] not in all_step_hasina]
not_in_step_hasina.extend([follower[i] for i in range(len(follower)) if follower[i] not in all_step_hasina])
not_in_step_hasina
# Out:
# []

# %%
############ shahjahanmustgo################

# %%
shahjahan = pd.read_excel('shahjahanmustgo.xlsx',index_col=0)

shahjahan.head()
# Out:
#                     usernameTweet  \
# ID
# 1025406947942494208   basherkella
# 1025406947942494208   basherkella
# 1026069370324353024   basherkella
# 1026069370324353024   basherkella
# 1024610449961013248  RahatAdnan17
#
#                                                                   text  \
# ID
# 1025406947942494208  Will you take dead body? Dead bodies of studen...
# 1025406947942494208  Will you take dead body? Dead bodies of studen...
# 1026069370324353024  Attack on @AP photojournalist AM Ahad: See how...
# 1026069370324353024  Attack on @AP photojournalist AM Ahad: See how...
# 1024610449961013248  Brave school and college students of #Banglade...
#
#                                                           url  nbr_retweet  \
# ID
# 1025406947942494208   /basherkella/status/1025406947942494208           90
# 1025406947942494208   /basherkella/status/1025406947942494208           89
# 1026069370324353024   /basherkella/status/1026069370324353024           42
# ...

# %%
user_id_lst = list(shahjahan['user_id'].unique())

len(user_id_lst)
# Out:
# 61

# %%
follower = pd.read_excel('follower_followed.xlsx',index_col=0)
follower_shahjahan = follower.loc[user_id_lst].copy()
follower_shahjahan.dropna(inplace=True)
follower = list(follower_shahjahan.index)

followed = pd.read_excel('follower_followed.xlsx',index_col=1)
followed_shahjahan = followed.loc[user_id_lst].copy()
followed_shahjahan.dropna(inplace=True)
followed = list(followed_shahjahan.index)

followed = list(set(followed))
follower = list(set(follower))
# Out:
# c:\users\alvira~1\deeple~1\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#
# c:\users\alvira~1\deeple~1\lib\site-packages\ipykernel_launcher.py:7: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   import sys

# %%
shahjahan_dict = {}
for i in range(len(followed)):
    if followed[i] in follower:
        shahjahan_dict[followed[i]] = True

        
for i in range(len(follower)):
    if follower[i] in followed:
        shahjahan_dict[follower[i]] = True

# %%
len(shahjahan_dict)
# Out:
# 56

# %%
all_shahjahan = list(shahjahan_dict.keys())

not_in_shahjahan = [followed[i] for i in range(len(followed)) if followed[i] not in all_shahjahan]

not_in_shahjahan.extend([follower[i] for i in range(len(follower)) if follower[i] not in all_shahjahan])

not_in_shahjahan
# Out:
# [804343111036059649,
#  1014447359093137409,
#  757248545724301312,
#  340951989,
#  1019699812390850560]

# %%
#############save democracy ##############

# %%
savedemocracy = pd.read_excel('savedemocracy.xlsx',index_col=0)

savedemocracy.head()
# Out:
#                        usernameTweet  \
# ID
# 1040871818083483649      haidersuman
# 1050744628331175936      haidersuman
# 1040903604347920384  Omihasa90445588
# 1055031045014339584          kostto2
# 1042004088727064577      Mujahid5558
#
#                                                                   text  \
# ID
# 1040871818083483649  # Fascist #SheikhHasina government has destroy...
# 1050744628331175936  # FreeKhaledaZia #FreeAllPoliticalPrisoners #F...
# 1040903604347920384  # Fascist #SheikhHasina government has destroy...
# 1055031045014339584  In front of the next election, the National Un...
# 1042004088727064577  # FreeKhaledaZia #FreeShahidulAlam #FreeALLPol...
#
#                                                              url  nbr_retweet  \
# ID
# 1040871818083483649      /haidersuman/status/1040871818083483649            3
# 1050744628331175936      /haidersuman/status/1050744628331175936            2
# ...

# %%
user_id_lst = list(savedemocracy['user_id'].unique())

len(user_id_lst)
# Out:
# 18

# %%
follower = pd.read_excel('follower_followed.xlsx',index_col=0)
follower_save_democracy = follower.loc[user_id_lst].copy()
follower_save_democracy.dropna(inplace=True)
follower = list(follower_save_democracy.index)

followed = pd.read_excel('follower_followed.xlsx',index_col=1)
followed_save_democracy = followed.loc[user_id_lst].copy()
followed_save_democracy.dropna(inplace=True)
followed = list(followed_save_democracy.index)

followed = list(set(followed))
follower = list(set(follower))
# Out:
# c:\users\alvira~1\deeple~1\lib\site-packages\ipykernel_launcher.py:7: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   import sys

# %%
save_democracy_dict = {}
for i in range(len(followed)):
    if followed[i] in follower:
        save_democracy_dict[followed[i]] = True

        
for i in range(len(follower)):
    if follower[i] in followed:
        save_democracy_dict[follower[i]] = True

# %%
len(save_democracy_dict)
# Out:
# 15

# %%
all_save_democracy = list(save_democracy_dict.keys())

not_in_save_democracy = [followed[i] for i in range(len(followed)) if followed[i] not in all_save_democracy]

not_in_save_democracy.extend([follower[i] for i in range(len(follower)) if follower[i] not in all_save_democracy])

not_in_save_democracy
# Out:
# [794139252225232896, 949076810, 1025462684706201600]

# %%
############stophoax#############

# %%
stophoax = pd.read_excel('stophoax.xlsx',index_col=0)

stophoax.head()
# Out:
#                     usernameTweet  \
# ID
# 1027070401451570048    MAlamHanif
# 1026808311063049984    MAlamHanif
# 1026471854062450048    DeadTonmoy
# 1026472749441510016   PijonZimtuj
# 1026981334546300032     Maksud_15
#
#                                                                   text  \
# ID
# 1027070401451570048  A group of people still blocking the roads eve...
# 1026808311063049984  # Bangladesh govt already accepted the 9 deman...
# 1026471854062450048  The #Bangladesh govt already accepted the 9 de...
# 1026472749441510016  The #Bangladesh govt already accepted the 9 de...
# 1026981334546300032  A group of people still blocking the roads eve...
#
#                                                          url  nbr_retweet  \
# ID
# 1027070401451570048   /MAlamHanif/status/1027070401451573248           10
# 1026808311063049984   /MAlamHanif/status/1026808311063052289           12
# 1026471854062450048   /DeadTonmoy/status/1026471854062456832            7
# ...

# %%
user_id_lst = list(stophoax['user_id'].unique())

len(user_id_lst)
# Out:
# 225

# %%
follower = pd.read_excel('follower_followed.xlsx',index_col=0)
follower_stop_hoax = follower.loc[user_id_lst].copy()
follower_stop_hoax.dropna(inplace=True)
follower = list(follower_stop_hoax.index)

followed = pd.read_excel('follower_followed.xlsx',index_col=1)
followed_stop_hoax = followed.loc[user_id_lst].copy()
followed_stop_hoax.dropna(inplace=True)
followed = list(followed_stop_hoax.index)

followed = list(set(followed))
follower = list(set(follower))
# Out:
# c:\users\alvira~1\deeple~1\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#
# c:\users\alvira~1\deeple~1\lib\site-packages\ipykernel_launcher.py:7: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   import sys

# %%
stop_hoax_dict = {}
for i in range(len(followed)):
    if followed[i] in follower:
        stop_hoax_dict[followed[i]] = True

        
for i in range(len(follower)):
    if follower[i] in followed:
        stop_hoax_dict[follower[i]] = True

# %%
len(stop_hoax_dict)
# Out:
# 105

# %%
all_stop_hoax = list(stop_hoax_dict.keys())
not_in_stop_hoax = [followed[i] for i in range(len(followed)) if followed[i] not in all_stop_hoax]
not_in_stop_hoax.extend([follower[i] for i in range(len(follower)) if follower[i] not in all_stop_hoax])
not_in_stop_hoax
# Out:
# [425347635, 3012293286, 3010980588, 3023364448, 3021219682, 3021166457]

# %%
############shahidul##############

# %%
shahidul = pd.read_excel('shahidul.xlsx',index_col=0)

shahidul.head()
# Out:
#                      usernameTweet  \
# ID
# 1027131769693200000  Shehla_Rashid
# 1050045531353939968        RupaHuq
# 1032074533191049984    sharonstone
# 1026735529914759936    ReallySwara
# 1065016174935709952    sharonstone
#
#                                                                   text  \
# ID
# 1027131769693200000  Strongly condemn Bangladesh govt's crackdown o...
# 1050045531353939968  Case of photo-journalist incarcerated and tort...
# 1032074533191049984  This is Shahidul Alam. A call to action for th...
# 1026735529914759936  # Bangladesh #FreeShahidulAlam https:// twitte...
# 1065016174935709952  Shahidul is out!!!! Thank you to all who helpe...
#
#                                                            url  nbr_retweet  \
# ID
# 1027131769693200000  /Shehla_Rashid/status/1027131769693200384          162
# 1050045531353939968        /RupaHuq/status/1050045531353944064          198
# 1032074533191049984    /sharonstone/status/1032074533191053312          149
# ...

# %%
user_id_lst = list(shahidul['user_id'].unique())

len(user_id_lst)
# Out:
# 1961

# %%
follower = pd.read_excel('follower_followed.xlsx',index_col=0)
follower_shahidul = follower.loc[user_id_lst].copy()
follower_shahidul.dropna(inplace=True)
follower = list(follower_shahidul.index)

followed = pd.read_excel('follower_followed.xlsx',index_col=1)
followed_shahidul = followed.loc[user_id_lst].copy()
followed_shahidul.dropna(inplace=True)
followed = list(followed_shahidul.index)

followed = list(set(followed))
follower = list(set(follower))
# Out:
# c:\users\alvira~1\deeple~1\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#
# c:\users\alvira~1\deeple~1\lib\site-packages\ipykernel_launcher.py:7: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   import sys

# %%
shahidul_dict = {}
for i in range(len(followed)):
    if followed[i] in follower:
        shahidul_dict[followed[i]] = True

        
for i in range(len(follower)):
    if follower[i] in followed:
        shahidul_dict[follower[i]] = True

# %%
len(shahidul_dict)
# Out:
# 999

# %%
all_shahidul = list(shahidul_dict.keys())
not_in_shahidul = [followed[i] for i in range(len(followed)) if followed[i] not in all_shahidul]
not_in_shahidul.extend([follower[i] for i in range(len(follower)) if follower[i] not in all_shahidul])
not_in_shahidul
# Out:
# [58386439,
#  2314672190,
#  2647091335,
#  203985048,
#  1663170722,
#  119410994,
#  1183383930,
#  2828448192,
#  1665534414,
#  3268383253,
#  30442011,
#  979053284,
#  347974406,
#  1672846104,
#  3131605787,
#  452877096,
#  2505548600,
#  437308264,
#  3305173903,
#  76383158,
#  2914167743,
#  15008782,
#  293975071,
#  2215474214,
#  2890484790,
#  141569093,
#  31421672,
#  453582151,
#  60886384,
#  178394509,
#  420949439,
#  2714318316,
#  12629592,
#  2487490152,
#  2930935453,
#  545840826,
#  2996703032,
#  3441244039,
#  43116435,
#  917250560880812032,
#  73072650,
#  142188566,
#  36937757,
#  3186941990,
#  310157353,
#  928211060,
#  205258928,
#  1139400883,
#  85516520,
#  2609504528,
#  84648330,
#  2807734682,
#  2771050913,
#  263381446,
#  99992010,
#  1454039550,
#  2464203284,
#  3281461783,
#  868868665,
#  1443480134,
#  192488009,
#  3328139989,
#  162374410,
#  1260241680,
#  85033744,
#  949076810,
#  166847405,
#  1670906802,
#  1968145459,
# ...

# %%
follower_followed = pd.read_excel('follower_followed.xlsx')

# %%
follower_followed.head()
# Out:
#              follower            followed
# 0  908437100701159424          2624575029
# 1  720681598656638976          2780855899
# 2  730928202898509824           849618397
# 3  730928202898509824  920556615408893952
# 4          3181572714  730928202898509824

# %%
tuple(follower_followed.iloc[0])
# Out:
# (908437100701159424, 2624575029)

# %%
nodes = list(follower_followed['follower'].unique())

# %%
nodes.extend(list(follower_followed['followed'].unique()))

# %%
nodes = list(set(nodes))

# %%
len(nodes)
# Out:
# 12417

# %%
edges = [tuple(follower_followed.iloc[i]) for i in range(len(follower_followed))]

# %%
import networkx as nx

G=nx.Graph()

# a list of nodes:
G.add_nodes_from(nodes)

G.add_edges_from(edges)

# %%
import matplotlib.pyplot as plt
nx.draw(G)
plt.savefig("graph.png") # save as png
plt.show() # display

# %%
import plotly.graph_objects as go

import networkx as nx

G = nx.random_geometric_graph(200, 0.125)

# %%
edge_x = []
edge_y = []
for edge in G.edges():
    x0, y0 = G.node[edge[0]]['pos']
    x1, y1 = G.node[edge[1]]['pos']
    edge_x.append(x0)
    edge_x.append(x1)
    edge_x.append(None)
    edge_y.append(y0)
    edge_y.append(y1)
    edge_y.append(None)

edge_trace = go.Scatter(
    x=edge_x, y=edge_y,
    line=dict(width=0.5, color='#888'),
    hoverinfo='none',
    mode='lines')

node_x = []
node_y = []
for node in G.nodes():
    x, y = G.node[node]['pos']
    node_x.append(x)
    node_y.append(y)

node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers',
    hoverinfo='text',
    marker=dict(
        showscale=True,
        # colorscale options
        #'Greys' | 'YlGnBu' | 'Greens' | 'YlOrRd' | 'Bluered' | 'RdBu' |
        #'Reds' | 'Blues' | 'Picnic' | 'Rainbow' | 'Portland' | 'Jet' |
        #'Hot' | 'Blackbody' | 'Earth' | 'Electric' | 'Viridis' |
        colorscale='YlGnBu',
        reversescale=True,
        color=[],
        size=10,
        colorbar=dict(
            thickness=15,
            title='Node Connections',
            xanchor='left',
            titleside='right'
        ),
        line_width=2))

# %%
import networkx as nx
import matplotlib.pyplot as plt

def draw_graph(graph):

    # extract nodes from graph
    nodes = set([n1 for n1, n2 in graph] + [n2 for n1, n2 in graph])

    # create networkx graph
    G=nx.Graph()

    # add nodes
    for node in nodes:
        G.add_node(node)

    # add edges
    for edge in graph:
        G.add_edge(edge[0], edge[1])

    # draw graph
    pos = nx.shell_layout(G)
    nx.draw(G, pos)
    
    # show graph
    plt.show()

# draw example
graph = edges[:10]
plt.figure(figsize=(20,10))
draw_graph(graph)

# %%
# Out:
# [(908437100701159424, 2624575029),
#  (720681598656638976, 2780855899),
#  (730928202898509824, 849618397),
#  (730928202898509824, 920556615408893952),
#  (3181572714, 730928202898509824),
#  (724135346724720640, 2987109259),
#  (2987109259, 724135346724720640),
#  (724135346724720640, 859060200690548742),
#  (859060200690548742, 724135346724720640),
#  (724135346724720640, 735730681104343040),
#  (735730681104343040, 724135346724720640),
#  (724135346724720640, 3166107949),
#  (3166107949, 724135346724720640),
#  (724135346724720640, 3183003265),
#  (3183003265, 724135346724720640),
#  (724135346724720640, 949255837754654722),
#  (949255837754654722, 724135346724720640),
#  (724135346724720640, 3187984788),
#  (3187984788, 724135346724720640),
#  (724135346724720640, 953776401034989568),
#  (953776401034989568, 724135346724720640),
#  (724135346724720640, 811958256),
#  (811958256, 724135346724720640),
#  (724135346724720640, 940323312634417154),
# ...
